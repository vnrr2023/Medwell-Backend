# %%
import requests

# %%
import pandas as pd

# %%
df=pd.DataFrame(
[
  { "intent": "welcome", "utterance": "Hello" },
  { "intent": "welcome", "utterance": "Hi there" },
  { "intent": "welcome", "utterance": "Good morning" },
  { "intent": "welcome", "utterance": "Good evening" },
  { "intent": "welcome", "utterance": "Greetings" },
  { "intent": "welcome", "utterance": "Hey!" },
  { "intent": "welcome", "utterance": "Howdy" },
  { "intent": "welcome", "utterance": "Hi!" },
  { "intent": "welcome", "utterance": "Hello, chatbot" },
  { "intent": "welcome", "utterance": "Good to see you" },
  { "intent": "welcome", "utterance": "Hey there" },
  { "intent": "welcome", "utterance": "Hi, how are you?" },
  { "intent": "welcome", "utterance": "Hello, anyone there?" },
  { "intent": "welcome", "utterance": "Hi! Can you help me?" },
  { "intent": "welcome", "utterance": "Hey, what’s up?" },
  { "intent": "welcome", "utterance": "Good afternoon" },
  { "intent": "welcome", "utterance": "Hi there, how’s it going?" },
  { "intent": "welcome", "utterance": "Is anyone here?" },
  { "intent": "welcome", "utterance": "Hello! Are you available?" },
  { "intent": "welcome", "utterance": "Hi chatbot!" },
  { "intent": "welcome", "utterance": "Hey, how do I start?" },
  { "intent": "welcome", "utterance": "Hello! What can you do?" },
  { "intent": "welcome", "utterance": "Hi there! What’s new?" },
  { "intent": "welcome", "utterance": "Hey! Can you assist me?" },
  { "intent": "welcome", "utterance": "Hello! I need help" },
  { "intent": "thank_you", "utterance": "Thank you" },
  { "intent": "thank_you", "utterance": "Thanks a lot" },
  { "intent": "thank_you", "utterance": "I appreciate it" },
  { "intent": "thank_you", "utterance": "Thanks for your help" },
  { "intent": "thank_you", "utterance": "Much appreciated" },
  { "intent": "thank_you", "utterance": "Thanks a ton" },
  { "intent": "thank_you", "utterance": "Thanks so much" },
  { "intent": "thank_you", "utterance": "Many thanks" },
  { "intent": "thank_you", "utterance": "Big thanks" },
  { "intent": "thank_you", "utterance": "Thanks for being so helpful" },
  { "intent": "thank_you", "utterance": "I’m grateful" },
  { "intent": "thank_you", "utterance": "I owe you one" },
  { "intent": "thank_you", "utterance": "Thanks for everything" },
  { "intent": "thank_you", "utterance": "Thanks again" },
  { "intent": "thank_you", "utterance": "I truly appreciate it" },
  { "intent": "thank_you", "utterance": "Forever grateful" },
  { "intent": "thank_you", "utterance": "I can’t thank you enough" },
  { "intent": "thank_you", "utterance": "Endless thanks" },
  { "intent": "thank_you", "utterance": "I’m much obliged" },
  { "intent": "thank_you", "utterance": "Grateful for your help" },
  { "intent": "thank_you", "utterance": "You’re the best!" },
  { "intent": "thank_you", "utterance": "I really appreciate your assistance" },
  { "intent": "thank_you", "utterance": "I’m deeply thankful" },
  { "intent": "bye", "utterance": "Goodbye" },
  { "intent": "bye", "utterance": "See you later" },
  { "intent": "bye", "utterance": "Bye for now" },
  { "intent": "bye", "utterance": "Catch you later" },
  { "intent": "bye", "utterance": "Talk to you soon" },
  { "intent": "bye", "utterance": "Take care" },
  { "intent": "bye", "utterance": "Bye-bye" },
  { "intent": "bye", "utterance": "See you again" },
  { "intent": "bye", "utterance": "Farewell" },
  { "intent": "bye", "utterance": "I’m off" },
  { "intent": "bye", "utterance": "Catch you on the flip side" },
  { "intent": "bye", "utterance": "See you next time" },
  { "intent": "bye", "utterance": "Hope to talk to you soon" },
  { "intent": "bye", "utterance": "Goodnight" },
  { "intent": "bye", "utterance": "Until next time" },
  { "intent": "bye", "utterance": "Adios!" },
  { "intent": "bye", "utterance": "See ya!" },
  { "intent": "bye", "utterance": "I’ll talk to you later" },
  { "intent": "bye", "utterance": "Catch up with you soon" },
  { "intent": "bye", "utterance": "Have a good one!" },
  { "intent": "bye", "utterance": "Peace out!" },
  { "intent": "bye", "utterance": "Later!" },
  { "intent": "bye", "utterance": "I’m signing off now" },
  { "intent": "bye", "utterance": "Ciao!" },
  { "intent": "help", "utterance": "What’s my hemoglobin trend?" },
  { "intent": "help", "utterance": "What’s the summary of my report?" },
  { "intent": "help", "utterance": "Can you show me my cholesterol levels?" },
  { "intent": "help", "utterance": "How is my blood sugar over time?" },
  { "intent": "help", "utterance": "What does my blood test indicate?" },
  { "intent": "help", "utterance": "Can you explain my test results?" },
  { "intent": "help", "utterance": "What’s my vitamin D status?" },
  { "intent": "help", "utterance": "Can you summarize my medical report?" },
  { "intent": "help", "utterance": "What’s the trend of my blood pressure?" },
  { "intent": "help", "utterance": "Can you highlight abnormalities in my report?" },
  { "intent": "help", "utterance": "How do I interpret my CBC report?" },
  { "intent": "help", "utterance": "What’s my overall health summary?" },
  { "intent": "help", "utterance": "Do I have any deficiencies?" },
  { "intent": "help", "utterance": "What’s my blood pressure trend?" },
  { "intent": "help", "utterance": "Are my test results normal?" },
  { "intent": "help", "utterance": "What does this medical term mean?" },
  { "intent": "help", "utterance": "What’s my health improvement score?" },
  { "intent": "help", "utterance": "How does this result compare to the last one?" },
  { "intent": "help", "utterance": "Am I within normal health ranges?" },
  { "intent": "help", "utterance": "Explain my blood glucose results" },
  { "intent": "help", "utterance": "What’s my WBC count trend?" },
  { "intent": "about", "utterance": "Tell me about yourself" },
  { "intent": "about", "utterance": "What can you do?" },
  { "intent": "about", "utterance": "What is this chatbot for?" },
  { "intent": "about", "utterance": "Who made you?" },
  { "intent": "about", "utterance": "Why were you created?" },
  { "intent": "about", "utterance": "Tell me your purpose" },
  { "intent": "about", "utterance": "What’s your name?" },
  { "intent": "about", "utterance": "Can you explain your features?" },
  { "intent": "about", "utterance": "What are your capabilities?" },
  { "intent": "about", "utterance": "Tell me more about this system" },
  { "intent": "about", "utterance": "How do you work?" },
  { "intent": "about", "utterance": "What is your main function?" },
  { "intent": "about", "utterance": "Are you human?" },
  { "intent": "about", "utterance": "What is your backend?" },
  { "intent": "about", "utterance": "How do you process requests?" },
  { "intent": "about", "utterance": "What language are you coded in?" },
  { "intent": "about", "utterance": "Do you have an upgrade?" },
  { "intent": "about", "utterance": "What technology powers you?" },
  { "intent": "about", "utterance": "Do you store user data?" },
  { "intent": "about", "utterance": "Are you safe to use?" },
  { "intent": "about", "utterance": "What’s your specialty?" }
]


)

# %%
df[df.intent=="help"]
# Out:
#    intent                                      utterance
# 72   help                    What’s my hemoglobin trend?
# 73   help               What’s the summary of my report?
# 74   help         Can you show me my cholesterol levels?
# 75   help               How is my blood sugar over time?
# 76   help              What does my blood test indicate?
# 77   help               Can you explain my test results?
# 78   help                    What’s my vitamin D status?
# 79   help           Can you summarize my medical report?
# 80   help         What’s the trend of my blood pressure?
# 81   help  Can you highlight abnormalities in my report?
# 82   help              How do I interpret my CBC report?
# 83   help              What’s my overall health summary?
# 84   help                    Do I have any deficiencies?
# 85   help                What’s my blood pressure trend?
# 86   help                    Are my test results normal?
# ...

# %%
import spacy

# %%
nlp=spacy.load("en_core_web_lg")

# %%
doc=nlp("hello")

# %%
df["vector"]=df.utterance.apply(lambda x:nlp(x).vector)

# %%
df=pickle.load(open("intent_df.pkl","rb"))

# %%
intent_mapping={}
for i,intent in enumerate(df.intent.unique()):
    intent_mapping[i]=intent

# %%
df["intent_map"]=df.intent.map(intent_mapping)

# %%
import pickle

# %%
pickle.dump(df,open("intent_df.pkl","wb"))

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
df
# Out:
#       intent                    utterance  \
# 0    welcome                        Hello
# 1    welcome                     Hi there
# 2    welcome                 Good morning
# 3    welcome                 Good evening
# 4    welcome                    Greetings
# ..       ...                          ...
# 109    about      Do you have an upgrade?
# 110    about  What technology powers you?
# 111    about      Do you store user data?
# 112    about         Are you safe to use?
# 113    about       What’s your specialty?
#
#                                                 vector  intent_map
# 0    [0.25233, 0.10176, -0.67485, 0.21117, 0.43492,...           0
# 1    [0.097988, 0.35949498, -0.30186, -0.1749825, 0...           0
# 2    [-0.08134, 0.50047, -0.2557, 0.092705004, -0.2...           0
# 3    [-0.0005699992, 0.35043, -0.024624988, 0.12941...           0
# 4    [-0.25058, -0.17122, -0.7486, -0.39892, 0.6774...           0
# ...

# %%
from sklearn.model_selection import GridSearchCV

# %%
svm_params = {
    'C': [0.1, 1, 10],
    'kernel': ['linear', 'rbf'],
    'gamma': ['scale', 'auto']
}

svm_grid_search = GridSearchCV(SVC(), svm_params, cv=5)
svm_grid_search.fit(np.stack(df.vector.values), df.intent_map)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10], 'gamma': ['scale', 'auto'],
#                          'kernel': ['linear', 'rbf']})

# %%
import numpy as np

# %%
np.stack(df.vector.values)
# Out:
# array([[ 0.25233   ,  0.10176   , -0.67485   , ...,  0.17869   ,
#         -0.51917   ,  0.33591   ],
#        [ 0.097988  ,  0.35949498, -0.30186   , ..., -0.0441485 ,
#         -0.10342   ,  0.1932515 ],
#        [-0.08134   ,  0.50047   , -0.2557    , ..., -0.2328635 ,
#         -0.3096155 ,  0.01303   ],
#        ...,
#        [ 0.02890083,  0.05141367, -0.29802164, ..., -0.04182583,
#          0.03182501,  0.27350202],
#        [ 0.01249867,  0.06064117, -0.29549834, ..., -0.14548935,
#          0.12952517,  0.22093832],
#        [-0.0386598 ,  0.238258  , -0.0794144 , ..., -0.07022499,
#          0.25966743,  0.02157514]], dtype=float32)

# %%
svm_best_model = svm_grid_search.best_estimator_

# %%
svm_best_model.score(np.stack(df.vector.values), df.intent_map)
# Out:
# 1.0

# %%
rf_params = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

rf_grid_search = GridSearchCV(RandomForestClassifier(random_state=42), rf_params, cv=5)
rf_grid_search.fit(np.stack(df.vector.values), df.intent_map)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42),
#              param_grid={'max_depth': [None, 10, 20],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [50, 100, 200]})

# %%
rf_best=rf_grid_search.best_estimator_

# %%
rf_best.score(np.stack(df.vector.values), df.intent_map)
# Out:
# 1.0

# %%
print(intent_mapping)
# Out:
# {0: 'welcome', 1: 'thank_you', 2: 'bye', 3: 'help', 4: 'about'}

# %%
question=input("enter question:")
vector=[nlp(question).vector]
predicted=rf_best.predict(vector)
print(intent_mapping[predicted[0]])
# Out:
# enter question: heyy hello
# [0]
# welcome

# %%
response_map={
    "welcome": [
    "Hey, I'm MedBuddy! I can help analyze your reports and answer questions like... For example, can you show me my hemoglobin trend?",
    "Hello! I'm MedBuddy, your electronic report assistant. How can I assist you with your health reports today?",
    "Heyy! i am medbuddy your electronic report assistant which answers questions by analyzing your reports. Eg: Whats my hemoglobin trend.."
    "Hello! I’m MedBuddy. I can provide insights on your medical reports. Would you like to know about your hemoglobin trends?",
    "Hi! I’m MedBuddy, your report assistant. Want to see your hemoglobin levels over the last few months?",
    "I’m MedBuddy! Need to analyze your medical reports? I can show you trends in hemoglobin, blood pressure, and more.",
    "Hey! It’s MedBuddy. I analyze your reports for you. Want to see your hemoglobin levels and how they’ve changed?",
    "Hi, MedBuddy here! I can help you track trends in your reports. Do you want to see how they’ve changed?",
    "Hi, I'm MedBuddy! Need help with your medical reports? I can show you the hemoglobin trends, blood pressure, and more.",
    "Hey! I’m MedBuddy. I analyze your health reports. Want me to summarize your hemoglobin trend or any other data?"
],
    "thank_you": [
      "You're welcome!",
      "Glad I could help!",
      "No problem at all!",
      "It was my pleasure!",
      "You're very welcome!",
      "Anytime, happy to help!",
      "Glad I could assist you!",
      "You're welcome, feel free to ask if you need anything!",
      "It was nothing, happy to help!",
      "You're welcome, take care!"
    ]
,
    "bye": [
      "Goodbye! Have a great day!",
      "See you later!",
      "Take care!",
      "Goodbye! Feel free to come back anytime!",
      "Bye! It was nice talking to you!",
      "Have a wonderful day ahead!",
      "Take care and see you soon!",
      "Goodbye! Don't hesitate to ask if you need anything else!",
      "See you soon, take care!",
      "Bye! Stay safe and take care!"
    ]
 ,
    "about": [
    "Hello! I'm MedBuddy, your Electronic Report Assistant, created by VNRR.",
    "Hi, I'm MedBuddy, your personalized Electronic Report Assistant, brought to you by VNRR.",
    "Greetings! I'm MedBuddy, your Electronic Report Assistant, designed by VNRR.",
    "Hey there! I'm MedBuddy, your trusty Electronic Report Assistant developed by VNRR.",
    "Hi! MedBuddy here, your Electronic Report Assistant, created by the team at VNRR.",
    "Hello, I'm MedBuddy, your Electronic Report Assistant, developed by VNRR to assist you.",
    "Greetings from MedBuddy, your Electronic Report Assistant, made by VNRR.",
    "Hey! I’m MedBuddy, your Electronic Report Assistant designed and created by VNRR.",
    "Hello, this is MedBuddy, your Electronic Report Assistant, built by VNRR.",
    "Hi, MedBuddy at your service! Your Electronic Report Assistant, designed by VNRR."
]
  }

# %%
pickle.dump(rf_best,open("chatbot.pkl","wb"))
